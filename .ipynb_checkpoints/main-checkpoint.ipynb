# %%
from rdkit import Chem

# %%
m  = Chem.MolFromSmiles("OCCc1c(C)[n+](cs1)Cc2cnc(C)nc2N")
m

# %%
# Out:
# <bound method GetAtoms of <rdkit.Chem.rdchem.Mol object at 0x00000252D8786640>>

# %%
print(Chem.MolFromSmiles("OCCc1c(C)[n+](cs1)Cc2cnc(C)nc2N"))
